# %%
import pandas as pd
import numpy as np
import os

# %%
# Import dataset from CSV files.

# %%
anime = pd.read_csv("anime.csv")
ratings = pd.read_csv("rating_complete.csv")

# %%
anime
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %%
ratings.head()
# Out:
#    user_id  anime_id  rating
# 0        0       430       9
# 1        0      1004       5
# 2        0      3010       7
# 3        0       570       7
# 4        0      2762       9

# %%
anime = anime.drop(columns=['Japanese name', 'Studios','Rating','Producers','Premiered','Type', 'Aired', 'Licensors','Members','Favorites','Source','Duration','Watching','Completed','On-Hold','Dropped','Plan to Watch','Score-10','Score-9','Score-8','Score-7','Score-6','Score-5','Score-4','Score-3','Score-2','Score-1'])
anime.head()
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
# 2       6                           Trigun  8.24
# 3       7               Witch Hunter Robin  7.27
# 4       8                   Bouken Ou Beet  6.98
#
#                                               Genres            English name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#   Episodes  Ranked  Popularity
# 0       26    28.0          39
# 1        1   159.0         518
# 2       26   266.0         201
# 3       26  2481.0        1467
# 4       52  3710.0        4369

# %%
#removes entries with no scores
anime = anime[ anime['Score'].str.contains('Unknown') == False]
anime = anime[ anime['Ranked'].str.contains('Unknown') == False]
#Removes entries that contain adult content
anime = anime[ anime['Genres'].str.contains("Hentai") == False]
anime.size
# Out:
# 88504

# %%
#converts values in these columns to numerical data types
anime['Score'] = anime['Score'].apply(pd.to_numeric)
anime['Ranked'] = anime['Ranked'].apply(pd.to_numeric)
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11063 entries, 0 to 17552
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MAL_ID        11063 non-null  int64
#  1   Name          11063 non-null  object
#  2   Score         11063 non-null  float64
#  3   Genres        11063 non-null  object
#  4   English name  11063 non-null  object
#  5   Episodes      11063 non-null  object
#  6   Ranked        11063 non-null  float64
#  7   Popularity    11063 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 777.9+ KB

# %%
for row in anime.index:
    if anime.loc[row, 'English name'] == 'Unknown':
        anime.loc[row, 'English name'] = anime.loc[row, 'Name']

# %%
#Removes shows that are less popular leaving only the top 60% of shows
pop_thresh = anime['Ranked'].max() * 0.60
print(pop_thresh)
print(len(anime))
anime_thresh = anime[anime['Ranked'] < pop_thresh]
print(len(anime_thresh))
# Out:
# 6644.4
# 11063
# 6646

# %%
anime = anime_thresh
print(len(anime))
# Out:
# 6646

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57633278 entries, 0 to 57633277
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 1.3 GB

# %%
# User should rate atleast 400 animies
n_ratings = ratings['user_id'].value_counts()
rate_thresh = ratings[ratings['user_id'].isin(n_ratings[n_ratings >= 400].index)].copy()
rate_thresh = rate_thresh[rate_thresh['user_id'] < rate_thresh['user_id'].max() * 0.5]
len(rate_thresh)
# Out:
# 12179381

# %%
rate_thresh
# Out:
#           user_id  MAL_ID  rating
# 1683           17    5781       7
# 1684           17    6682      10
# 1685           17   14199       2
# 1686           17   12355       6
# 1687           17   23673       6
# ...           ...     ...     ...
# 28721664   176690    2494       8
# 28721665   176690   17895       8
# 28721666   176690     268       7
# 28721667   176690   16005       8
# 28721668   176690    1589       8
#
# [12179381 rows x 3 columns]

# %%
ratings = rate_thresh

# %%
ratings = ratings.rename(index = str, columns={"anime_id":"MAL_ID"})
anime_merged = anime.merge(ratings, on = 'MAL_ID')
print(len(anime_merged))
# Out:
# 10834984

# %%
anime_merged.info()
anime_merged
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10834984 entries, 0 to 10834983
# Data columns (total 10 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   MAL_ID        int64
#  1   Name          object
#  2   Score         float64
#  3   Genres        object
#  4   English name  object
#  5   Episodes      object
#  6   Ranked        float64
#  7   Popularity    int64
#  8   user_id       int64
#  9   rating        int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 909.3+ MB
#           MAL_ID                 Name  Score  \
# 0              1         Cowboy Bebop   8.78
# 1              1         Cowboy Bebop   8.78
# 2              1         Cowboy Bebop   8.78
# 3              1         Cowboy Bebop   8.78
# 4              1         Cowboy Bebop   8.78
# ...          ...                  ...    ...
# 10834979   48456  SK∞: Crazy Rock Jam   6.52
# 10834980   48456  SK∞: Crazy Rock Jam   6.52
# 10834981   48456  SK∞: Crazy Rock Jam   6.52
# ...

# %%
os.path.exists('anime_ratings_merged.csv')
# Out:
# True

# %%
if os.path.exists('anime_ratings_merged.csv'):
    os.remove('anime_ratings_merged.csv')
anime_merged.to_csv('anime_ratings_merged.csv')

# %%
if os.path.exists('anime_cleaned.csv'):
    os.remove('anime_cleaned.csv')
anime.to_csv('anime_cleaned.csv')
